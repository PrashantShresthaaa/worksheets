# %%
import pandas as pd
df= pd.read_csv('/content/drive/MyDrive/datasetsworkshop1/Copy of Copy of Titanic-Dataset.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#problem 1
fare = df[['Fare']]
print(fare.head())


#creating a dataframe
class_age = df[['Pclass', 'Age']]# selecting two columns
class_age.head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
# Extracting the survived and sex columns
survived_gender = df[['Survived', 'Sex']]

survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
#problem 2
fare_gt_100=df[df['Fare']>100]
fare_gt_100
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
first_class=df[df['Pclass']==1]
first_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
femalebelow18 = df[(df['Age'] < 18) & (df['Sex'] == 'female')]
femalebelow18.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22           23         1       3           McGowan, Miss. Anna "Annie"
# 24           25         0       3         Palsson, Miss. Torborg Danira
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 22  female  15.0      0      0   330923   8.0292   NaN        Q
# 24  female   8.0      3      1   349909  21.0750   NaN        S

# %%
# 2.2(1)Filter passengers who embarked at Cherbourg ('C') or Southampton ('S')
embarked_c_or_s = df[df['Embarked'].isin(['C', 'S'])]#is in function prints data for c and s in embarked column
embarked_c_or_s.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
first_second_class=df[df['Pclass'].isin([1,2])] #same as above is in function used
first_second_class.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %%
# Handling missing values in Age by filling with the median
df['Age'].fillna(df['Age'])
# Add a column fare per year
df['fare_per_year'] = df['Fare'] / df['Age']
df['fare_per_year']
# Out:
# 0      0.329545
# 1      1.875876
# 2      0.304808
# 3      1.517143
# 4      0.230000
#          ...
# 886    0.481481
# 887    1.578947
# 888         NaN
# 889    1.153846
# 890    0.242188
# Name: fare_per_year, Length: 891, dtype: float64

# %%
# Filter for passengers with fare per yearmore than
high_fare_age=df[df['fare_per_year']>5]
high_fare_age.head()
# Out:
#     PassengerId  Survived  Pclass                                      Name  \
# 7             8         0       3            Palsson, Master. Gosta Leonard
# 16           17         0       3                      Rice, Master. Eugene
# 27           28         0       1            Fortune, Mr. Charles Alexander
# 43           44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 50           51         0       3                Panula, Master. Juha Niilo
#
#        Sex   Age  SibSp  Parch         Ticket      Fare        Cabin Embarked  \
# 7     male   2.0      3      1         349909   21.0750          NaN        S
# 16    male   2.0      4      1         382652   29.1250          NaN        Q
# 27    male  19.0      3      2          19950  263.0000  C23 C25 C27        S
# 43  female   3.0      1      2  SC/Paris 2123   41.5792          NaN        C
# 50    male   7.0      4      1        3101295   39.6875          NaN        S
#
#     fare_per_year
# 7       10.537500
# ...

# %%
high_fare_age_srt=high_fare_age.sort_values(by='fare_per_year', ascending=False)
high_fare_age_srt.head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 297          298         0       1     Allison, Miss. Helen Loraine  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 183          184         1       2        Becker, Master. Richard F    male
#
#       Age  SibSp  Parch   Ticket      Fare    Cabin Embarked  fare_per_year
# 305  0.92      1      2   113781  151.5500  C22 C26        S     164.728261
# 297  2.00      1      2   113781  151.5500  C22 C26        S      75.775000
# 386  1.00      5      2  CA 2144   46.9000      NaN        S      46.900000
# 164  1.00      4      1  3101295   39.6875      NaN        S      39.687500
# 183  1.00      2      1   230136   39.0000       F4        S      39.000000

# %%
result = high_fare_age_srt[['Name', 'fare_per_year']]

result
# Out:
#                                        Name  fare_per_year
# 305          Allison, Master. Hudson Trevor     164.728261
# 297            Allison, Miss. Helen Loraine      75.775000
# 386         Goodwin, Master. Sidney Leonard      46.900000
# 164            Panula, Master. Eino Viljami      39.687500
# 183               Becker, Master. Richard F      39.000000
# ..                                      ...            ...
# 318                Wick, Miss. Mary Natalie       5.318281
# 348  Coutts, Master. William Loch "William"       5.300000
# 205              Strom, Miss. Telma Matilda       5.231250
# 813      Andersson, Miss. Ebba Iris Alfrida       5.212500
# 480          Goodwin, Master. Harold Victor       5.211111
#
# [68 rows x 2 columns]

# %%
# Filter for male passengers who are adult
adult_males = df[(df['Sex'] == 'male') & (df['Age'] >= 18)]
adult_males.head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked  fare_per_year
# 0       1      0  A/5 21171   7.2500   NaN        S       0.329545
# 4       0      0     373450   8.0500   NaN        S       0.230000
# 6       0      0      17463  51.8625   E46        S       0.960417
# 12      0      0  A/5. 2151   8.0500   NaN        S       0.402500
# 13      1      5     347082  31.2750   NaN        S       0.801923

# %%
# Sort by 'fare_per_class' in descending order
asd= adult_males.sort_values(by='fare_per_class', ascending=False)

asd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a3ebbee4ae6> in <cell line: 2>()
#       1 # Sort by 'fare_per_class' in descending order
# ----> 2 asd= adult_males.sort_values(by='fare_per_class', ascending=False)
#       3
#       4 asd.head()
#
# NameError: name 'adult_males' is not defined

# %%
# SelectName,Age and fare_per_class columns
result_male_fare = asd[['Name', 'Age', 'fare_per_class']]
result_male_fare.head()

# %%
#GroupBy Method
#3.3START
#total fare all paasengers are
total_fare =df['Fare'].sum()
print(f"Total Fare: {total_fare}")

# %%
#total fare for each class, 3.2 Which passenger had the highest fare paid relative to their age?
first_class_fare = df[df['Pclass'] == 1]['Fare'].sum()
second_class_fare = df[df['Pclass'] == 2]['Fare'].sum()
third_class_fare = df[df['Pclass'] == 3]['Fare'].sum()

print(f"First Class Fare: {first_class_fare}")
print(f"Second Class Fare: {second_class_fare}")
print(f"Third Class Fare: {third_class_fare}")

# %%
# #Which adult male passenger (age ≥ 18 and Sex is ’male’) paid the highest fare relative to their
# class?
#the proportion of total fare revenue for each class
first_class_percentage = (first_class_fare / total_fare) * 100
second_class_percentage = (second_class_fare / total_fare) * 100
third_class_percentage = (third_class_fare / total_fare) * 100

print(f"First Class Fare Percentage: {first_class_percentage:.2f}%")
print(f"Second Class Fare Percentage: {second_class_percentage:.2f}%")
print(f"Third Class Fare Percentage: {third_class_percentage:.2f}%")

# %%
#3.3 Data analysis groupbyMetod
import numpy as np
conditions = [
    (df['Age'] < 18),
    (df['Age'] >= 18) & (df['Age'] < 65),
    (df['Age'] >= 65)
]
choices = ['child', 'adult', 'senior']

df['age_group'] =np.select(conditions, choices, default='adult')

df.head()

# %%
# What percent of the total number of passengers on the Titanic belonged to each age group
# (e.g., child, adult, senior)?
# Count passngers in age group
age_group_counts = df['age_group'].value_counts()

# Total of passengers
total_passengers = len(df)

# Percent for each age group
age_group_percentage = (age_group_counts / total_passengers) * 100

# Show percentage for age groups
age_group_percentage
